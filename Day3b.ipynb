# %% [markdown]
# # Python basics 2

# %%
point = (10,20) #Esto son tuplas, no listas
print(type(point))
# Out:
# <type 'tuple'>

# %%
x,y=point
x
# Out:
# 10

# %%
print(point[0])
point[0]=1 #No podemos hacer esto, las tuplas no cambian
# Out:
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d50b51e3d59d> in <module>()
#       1 print(point[0])
# ----> 2 point[0]=1 #No podemos hacer esto, las tuplas no cambian
#
# TypeError: 'tuple' object does not support item assignment

# %%
par={"par1" :1.0,
    "par2" : 2.0,
    "par3" : 3.0} # Esto es un diccionario, los datos se pueden acceder 
                    #por nombre

# %%
par["par2"]
# Out:
# 2.0

# %%
par["par4"]=4.0

# %%
par
# Out:
# {'par1': 1.0, 'par2': 2.0, 'par3': 3.0, 'par4': 4.0}

# %% [markdown]
# ## Condicionales

# %%
statement1=False
statement2=False

if statement1:
    print("Statement 1 es verdad")
elif not statement2:
    print("Carry on, nothing to see here")
else:
    print("Statement 1 es mentira :(")
# Out:
# Carry on, nothing to see here

# %%
statement1=True
statement2=False

if not statement1:
    if not statement2:
        print("Las dos son mentira :0")
else:
    print("Yep, una es verdad")
# Out:
# Yep, una es verdad

# %%
for x in range(1,5):
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
for key,value in par.items:
    print(key,"is",value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-69d9d3394dea> in <module>()
# ----> 1 for key,value in par.items:
#       2     print(key,"is",value)
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
l1=[x**2 for x in range(0,5)]
print(l1)
# Out:
# [0, 1, 4, 9, 16]

# %%
def func1(s):
    """
    Mira que bien, estoy documentando
    """
    print("El argumento es "+s)

# %%
func1("hola")
# Out:
# El argumento es hola

# %%
help(func1)
# Out:
# Help on function func1 in module __main__:
#
# func1(s)
#     Mira que bien, estoy documentando

# %%
def square(x):
    return(x**2)

# %%
square(2)
# Out:
# 4

# %%
def powers(x):
    return x**1,x**2,x**3

# %%
type(powers(3.))
# Out:
# tuple

# %%
def myfunc(x,p=2,debug=False):
    return(x**p)

# %%
print(myfunc(2,3))
# Out:
# 4

# %%
f1= lambda x:x**2

# %%
f1(3)
# Out:
# 9

# %%
class Point:
    """
    Clase para punto
    """
    def __init__(self,x,y):
        """
        Crea un punto
        """
        self.x=x
        self.y=y
    
    def translate(self, dx, dy):
        """
        Translada el punto
        """
        self.x += dx
        self.y += dy
    
    def __str__(self):
        return("Punto en [%f, %f]" % (self.x, self.y))

# %%
p1=Point(0,10)

# %%
type(p1)
# Out:
# instance

# %%
print(p1)
# Out:
# Punto en [0.000000, 10.000000]

# %%
p1.translate(1,2)

# %%
print(p1)
# Out:
# Punto en [1.000000, 12.000000]

# %%
try:
    print(test)
except Exception as e:
    print("No test: "+str(e))
# Out:
# No test: name 'test' is not defined

# %%
print(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-6043ef79dd3d> in <module>()
# ----> 1 print(test)
#
# NameError: name 'test' is not defined

# %% [markdown]
# ## Plots

# %%
# %matplotlib inline
# Out:
# /home/csat8786/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np #numerical python

# %%
x=np.arange(0,1,0.1)
y=x**2
plt.plot(x,y)

# %%
plt.plot(x,y,linewidth=3,linestyle='dashed',color='green')

# %%
plt.plot(x,y,linewidth=3,linestyle='dashed',color='green',marker='o',markersize=10)

# %%
yerr=np.ones(x.size)*0.1
plt.errorbar(x,y,yerr=yerr,label='Test data')
plt.legend(frameon=False,loc=0)
plt.show()

# %%
plt.plot(x,y)
plt.xlim=([0,0.5])

# %%
fig=plt.figure(figsize=(6,8))
axes=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes()
axes.plot(x,y,'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Title')

# %%
fig,axis=plt.subplots(nrows=1,ncols=2)

axis[0].plot(x,y,'r')
axis[1].plot(y,x,'orange')
fig.tight_layout #Para poner automaticamente el layout
# Out:
# <bound method Figure.tight_layout of <matplotlib.figure.Figure object at 0x7f6b17852190>>

# %%
fig,ax=plt.subplots()

ax.plot(x,x**2,label=r"$y=x^2$")
ax.plot(x,x,label=r"$y=\frac{x^2}{x}$")
plt.legend(loc=0)

# %%
fig,ax=plt.subplots()

ax.plot(x,x**2,label=r"$y=x^2$")
ax.plot(x,x,label=r"$y=\frac{x^2}{x}$")
plt.legend(loc=0)
ax.set_yscale("log")
ax.set_xticks([0,0.2,0.4,0.6,0.8])
ax.ser_xticklabels([0,r"$\alpha$",0.4,0.6,0.8])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-93d97dec8311> in <module>()
#       6 ax.set_yscale("log")
#       7 ax.set_xticks([0,0.2,0.4,0.6,0.8])
# ----> 8 ax.ser_xticklabels([0,r"$\alpha$",0.4,0.6,0.8])
#
# AttributeError: 'AxesSubplot' object has no attribute 'ser_xticklabels'

# %%
fig,ax=plt.subplots()

ax.plot(x,x**2,label=r"$y=x^2$")
ax.plot(x,x,label=r"$y=\frac{x^2}{x}$")
plt.legend(loc=0)
ax.grid(color='k', alpha=0.4, linestyle='dashed')
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")

# %%
fig,ax=plt.subplots()

ax.plot(x,x**2,label=r"$y=x^2$")
ax.plot(x,x,label=r"$y=\frac{x^2}{x}$")
plt.legend(loc=0)
ax.grid(color='k', alpha=0.4, linestyle='dashed')
ax.spines["top"].set_color("none")
ax2=ax.twinx()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
alpha=0.7
phi_ext=2*np.pi*0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2*np.cos(phi_p)*np.cos(phi_m) - alpha*np.cos(phi_ext - 2*phi_p)

# %%
phi_m=np.linspace(0, 2*np.pi, 100)
phi_p=np.linspace(0, 2*np.pi, 100)
X,Y=np.meshgrid(phi_p,phi_m)
Z=flux_qubit_potential(X,Y).T #.T es la traspuesta

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1, projection='3d')
p= ax.plot_wireframe(X,Y, Z, rstride=4, cstride=4)

# %%
from ipywidgets import interact
def pltwxy(az,el):
    fig=plt.figure(figsize=(20,10))
    ax=fig.add_subplot(1,2,1, projection="3d")
    ax.plot_surface(X,Y,Z, rstride=4, cstride=4, alpha=0.25)
    ax.view_init(az,el)
    
interact(pltwxy, az=(0,100,10),el=(0,90,30))
